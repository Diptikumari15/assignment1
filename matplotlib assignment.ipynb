# %%
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using 
the Pyplot module of Matplotlib.

# %%
Answer:
    Matplotlib is a  plotting library for the Python programming language. 
    It allows users to create a wide variety of static, animated, and interactive
    plots in Python. Matplotlib is widely used for data visualization and is often 
    used in conjunction with NumPy.
    
    It is used for visualizing data in a graphical format, making it easier to 
    understand trends, patterns, and relationships within the data. 
    
    Here are five types of plots that can be created using the Pyplot module:
    1.Line Plot:
      Used to visualize data points connected by straight line segments.
      Example: plt.plot(x, y)
    
    2.Scatter Plot:
      Represents individual data points on a two-dimensional graph.
      Example: plt.scatter(x, y)

    3.Histogram:
      Displays the distribution of a dataset by dividing it into bins and counting 
      the number of occurrences in each bin.
      Example: plt.hist(data, bins)

    4.Bar Plot:
      Represents data with rectangular bars. Can be used for categorical data.
      Example: plt.bar(categories, values)

    5.Pie Chart:
    Shows the proportion of each data category as a slice of a circular pie. 
      Example: plt.pie(values, labels)

# %%
Q2: What is a scatter plot? Use the following code to generate data for x and y.
Using this generated data plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
Note: Also add title, xlabel, and ylabel to the plot.

# %%
Answer:
    A scatter plot is a type of data visualization that displays individual data 
    points on a two-dimensional graph. Each point represents the values of two variables,
    and the position of the point on the graph corresponds to the values of those variables.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.xlabel("this is x ")
plt.ylabel("this is y")
plt.title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %%
Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %%
Answer:
    The subplot() function in Matplotlib is used to create multiple plots within
    a single figure. 
    This is useful when you want to compare multiple plots side by side or create
    a complex layout.

# %%
import numpy as np
x = np.array([0, 1, 2, 3, 4, 5])
y1  = np.array([0, 100, 200, 300, 400, 500])
y2 = np.array([50, 20, 40, 20, 60, 70])
y3  = np.array([10, 20, 30, 40, 50, 60])
y4  = np.array([200, 350, 250, 550, 450, 150])

plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

plt.tight_layout()

plt.show()

# %%
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot 
and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
Answer:
    A bar plot is a type of data visualization that represents categorical data 
    with rectangular bars. The length of each bar is proportional to the value 
    it represents.
    
    Bar plots are useful for comparing the values of different 
    categories and showing the distribution or magnitude of a dataset.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
Answer:
    A box plot, also known as a box-and-whisker plot, is a statistical visualization
    that displays the distribution of a dataset. It summarizes the central tendency
    and spread of the data, highlighting key summary statistics such as the median, 
    quartiles, and potential outliers. 
    Box plots are particularly useful for comparing
    the distribution of multiple datasets.

    In a box plot, the box represents the interquartile range (IQR) between the first
    (Q1) and third (Q3) quartiles, and the line inside the box represents the median.
    Whiskers extend from the box to show the range of the data, and potential outliers 
    are often displayed as individual points.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]
plt.boxplot(data, labels=['Box 1', 'Box 2'])
plt.show()
